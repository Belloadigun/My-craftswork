# %%
import pandas as pd

# %%
abj = pd.read_csv('Abuja_Branch.csv')

# %%
lag = pd.read_csv('Lagos_Branch.csv')

# %%
phc = pd.read_csv('Port_Harcourt_Branch.csv')

# %%
frames = [abj, lag, phc]
dataset = pd.concat(frames)
dataset
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    692-92-5582      B          Abuja        Member  Female
# 1    351-62-0822      B          Abuja        Member  Female
# 2    529-56-3974      B          Abuja        Member    Male
# 3    299-46-1805      B          Abuja        Member  Female
# 4    319-50-3348      B          Abuja        Normal  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0        Food and beverages     19742.4         3   2961.36   62188.56
# 1       Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
dataset.to_csv('Dataset.csv')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_csv('Dataset.csv')
# Out:
#      Unnamed: 0   Invoice ID Branch           City Customer type  Gender  \
# 0             0  692-92-5582      B          Abuja        Member  Female
# 1             1  351-62-0822      B          Abuja        Member  Female
# 2             2  529-56-3974      B          Abuja        Member    Male
# 3             3  299-46-1805      B          Abuja        Member  Female
# 4             4  319-50-3348      B          Abuja        Normal  Female
# 5             5  371-85-5789      B          Abuja        Normal    Male
# 6             6  273-16-6619      B          Abuja        Normal    Male
# 7             7  649-29-6775      B          Abuja        Normal    Male
# 8             8  145-94-9061      B          Abuja        Normal  Female
# 9             9  871-79-8483      B          Abuja        Normal    Male
# 10           10  149-71-6266      B          Abuja        Member    Male
# 11           11  640-49-2076      B          Abuja        Normal    Male
# ...

# %%
dataset.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
dataset.shape
# Out:
# (1000, 17)

# %%
dataset.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# ...

# %% [markdown]
# ### From the dataset statistical summary it can be observed that the row labels are the statistical aggregations carried out and the column labels consist of the original labels of the data including the 'total' column that sums up the results of each row label

# %%
dataset.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# 5         False   False  False          False   False         False
# 6         False   False  False          False   False         False
# 7         False   False  False          False   False         False
# 8         False   False  False          False   False         False
# 9         False   False  False          False   False         False
# 10        False   False  False          False   False         False
# 11        False   False  False          False   False         False
# 12        False   False  False          False   False         False
# ...

# %%
dataset.isnull().sum
# Out:
# <bound method DataFrame.sum of      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# 5         False   False  False          False   False         False
# 6         False   False  False          False   False         False
# 7         False   False  False          False   False         False
# 8         False   False  False          False   False         False
# 9         False   False  False          False   False         False
# 10        False   False  False          False   False         False
# 11        False   False  False          False   False         False
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 327
# Data columns (total 17 columns):
# Invoice ID                 1000 non-null object
# Branch                     1000 non-null object
# City                       1000 non-null object
# Customer type              1000 non-null object
# Gender                     1000 non-null object
# Product line               1000 non-null object
# Unit price                 1000 non-null float64
# Quantity                   1000 non-null int64
# Tax 5%                     1000 non-null float64
# Total                      1000 non-null float64
# Date                       1000 non-null object
# Time                       1000 non-null object
# Payment                    1000 non-null object
# cogs                       1000 non-null float64
# gross margin percentage    1000 non-null float64
# gross income               1000 non-null float64
# Rating                     1000 non-null float64
# ...

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
print(dataset['Date'].dtypes)
# Out:
# datetime64[ns]

# %%
dataset['Time'] = pd.to_datetime(dataset['Time'])

# %%
print(dataset['Time'].dtypes)
# Out:
# datetime64[ns]

# %%
import datetime as dt

# %%
dataset['Day']= dataset['Date'].dt.day

# %%
dataset['Month']= dataset['Date'].dt.month

# %%
dataset['Year']= dataset['Date'].dt.year

# %%
dataset['Hour']= dataset['Time'].dt.hour

# %%
print(dataset['Hour'].unique())
# Out:
# [13 18 17 16 15 10 12 19 14 11 20]

# %%
print(dataset['Hour'].nunique())
# Out:
# 11

# %%
categorical_columns = [col for col in dataset.columns if dataset[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
dataset['Invoice ID'].unique().tolist()
# Out:
# ['692-92-5582',
#  '351-62-0822',
#  '529-56-3974',
#  '299-46-1805',
#  '319-50-3348',
#  '371-85-5789',
#  '273-16-6619',
#  '649-29-6775',
#  '145-94-9061',
#  '871-79-8483',
#  '149-71-6266',
#  '640-49-2076',
#  '777-82-7220',
#  '280-35-5823',
#  '354-25-5821',
#  '132-32-9879',
#  '370-41-7321',
#  '727-46-3608',
#  '669-54-1719',
#  '616-24-2851',
#  '242-55-6721',
#  '347-34-2234',
#  '853-23-2453',
#  '109-28-2512',
#  '510-95-6347',
#  '847-38-7188',
#  '318-68-5053',
#  '152-08-9985',
#  '766-85-7061',
#  '733-01-9107',
#  '716-39-1409',
#  '479-26-8945',
#  '227-78-1148',
#  '291-32-1427',
#  '659-65-8956',
#  '378-24-2715',
#  '219-22-9386',
#  '268-27-6179',
#  '549-84-7482',
#  '191-10-6171',
#  '695-51-0018',
#  '590-83-4591',
#  '241-72-9525',
#  '262-47-2794',
#  '608-96-3517',
#  '279-74-2924',
#  '307-85-2293',
#  '743-04-1105',
#  '423-57-2993',
#  '548-46-9322',
#  '505-02-0892',
#  '316-55-4634',
#  '608-27-6295',
#  '414-12-7047',
#  '895-66-0685',
# ...

# %%
dataset['Product line'].unique().tolist()
# Out:
# ['Food and beverages',
#  'Fashion accessories',
#  'Electronic accessories',
#  'Sports and travel',
#  'Home and lifestyle',
#  'Health and beauty']

# %%
dataset['City'].unique().tolist()
# Out:
# ['Abuja', 'Lagos', 'Port Harcourt']

# %%
dataset['Gender'].unique().tolist()
# Out:
# ['Female', 'Male']

# %%
dataset['Payment'].unique().tolist()
# Out:
# ['Card', 'Epay', 'Cash']

# %%
dataset['Customer type'].unique().tolist()
# Out:
# ['Member', 'Normal']

# %%
print("Total Number of unique values in the Payment Column : {}". format(len(dataset['Payment'].unique().tolist())))
print("Total Number of unique values in the Customer type Column : {}". format(len(dataset['Customer type'].unique().tolist())))
print("Total Number of unique values in the Gender Column : {}". format(len(dataset['Gender'].unique().tolist())))
print("Total Number of unique values in the City Column : {}". format(len(dataset['City'].unique().tolist())))
print("Total Number of unique values in the Product line Column : {}". format(len(dataset['Product line'].unique().tolist())))
print("Total Number of unique values in the Invoice ID Column : {}". format(len(dataset['Invoice ID'].unique().tolist())))
# Out:
# Total Number of unique values in the Payment Column : 3
# Total Number of unique values in the Customer type Column : 2
# Total Number of unique values in the Gender Column : 2
# Total Number of unique values in the City Column : 3
# Total Number of unique values in the Product line Column : 6
# Total Number of unique values in the Invoice ID Column : 1000

# %%
dataset['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
dataset['City'].value_counts()
# Out:
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64

# %%
dataset['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
dataset['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
dataset['Invoice ID'].value_counts()
# Out:
# 700-81-1757    1
# 584-86-7256    1
# 458-10-8612    1
# 821-07-3596    1
# 740-22-2500    1
# 243-55-8457    1
# 342-65-4817    1
# 459-45-2396    1
# 862-17-9201    1
# 689-05-1884    1
# 305-18-3552    1
# 102-77-2261    1
# 622-20-1945    1
# 394-41-0748    1
# 263-10-3913    1
# 834-45-5519    1
# 589-02-8023    1
# 635-28-5728    1
# 816-72-8853    1
# 886-54-6089    1
# 787-15-1757    1
# 327-40-9673    1
# 283-79-9594    1
# 702-83-5291    1
# 316-55-4634    1
# 732-67-5346    1
# 318-68-5053    1
# 559-61-5987    1
# 365-16-4334    1
# 258-69-7810    1
#               ..
# 502-05-1910    1
# 127-47-6963    1
# 741-73-3559    1
# 181-94-6432    1
# 361-59-0574    1
# 530-90-9855    1
# 137-63-5492    1
# 149-15-7606    1
# 835-16-0096    1
# 588-01-7461    1
# 797-88-0493    1
# 866-05-7563    1
# 848-24-9445    1
# 631-41-3108    1
# 634-97-8956    1
# 842-40-8179    1
# 238-45-6950    1
# 595-86-2894    1
# 522-57-8364    1
# 731-59-7531    1
# 308-81-0538    1
# ...

# %%
dataset['Payment'].value_counts()
# Out:
# Epay    345
# Cash    344
# Card    311
# Name: Payment, dtype: int64

# %%
group_by = dataset.groupby(by ='City').sum()
group_by
# Out:
#                Unit price  Quantity      Tax 5%        Total        cogs  \
# City
# Abuja           6652396.8      1820  1820531.52  38231161.92  36410630.4
# Lagos           6705176.4      1859  1820577.78  38232133.38  36411555.6
# Port Harcourt   6684393.6      1831  1895463.54  39804734.34  37909270.8
#
#                gross margin percentage  gross income  Rating   Day  Month  \
# City
# Abuja                      1580.952381    1820531.52  2263.6  5068    665
# Lagos                      1619.047619    1820577.78  2389.2  5232    688
# Port Harcourt              1561.904762    1895463.54  2319.9  4956    640
#
#                  Year  Hour
# City
# Abuja          670308  5029
# Lagos          686460  4987
# Port Harcourt  662232  4894

# %% [markdown]
# ## Port Harcout is the city with highest total gross income

# %%
group_by2 = dataset.groupby(by='City').mean()
group_by2
# Out:
#                  Unit price  Quantity       Tax 5%          Total  \
# City
# Abuja          20037.339759  5.481928  5483.528675  115154.102169
# Lagos          19721.107059  5.467647  5354.640529  112447.451118
# Port Harcourt  20379.248780  5.582317  5778.852256  121355.897378
#
#                         cogs  gross margin percentage  gross income    Rating  \
# City
# Abuja          109670.573494                 4.761905   5483.528675  6.818072
# Lagos          107092.810588                 4.761905   5354.640529  7.027059
# Port Harcourt  115577.045122                 4.761905   5778.852256  7.072866
#
#                      Day     Month    Year       Hour
# City
# Abuja          15.265060  2.003012  2019.0  15.147590
# Lagos          15.388235  2.023529  2019.0  14.667647
# Port Harcourt  15.109756  1.951220  2019.0  14.920732

# %% [markdown]
# ## Step 6 - Data Visualization

# %%
Group_by =dataset.groupby(['Branch'])['Quantity'].sum()
Group_by
# Out:
# Branch
# A    1859
# B    1820
# C    1831
# Name: Quantity, dtype: int64

# %%
sns.countplot(x= 'Quantity',hue = 'Branch', data = dataset)

# %%
sns.countplot(x = 'Payment',hue= 'City', data = dataset)

# %%
sns.countplot(y = 'Product line', data = dataset)

# %%
sns.countplot(y = 'Product line',hue = 'Payment',  data = dataset)

# %%
sns.countplot(x= 'Payment', hue= 'Branch', data= dataset)

# %%
dataset.boxplot(column="Rating",by="Branch")

# %% [markdown]
# ## The first quartile and third quartile of Branch B is the lowest denoting that Branch B has the lowest rating

# %%
import seaborn as sns
sns.catplot(x = "Product line",y = "Quantity",
                hue= "Gender",
                data= dataset,
                kind = "box", aspect = 4)

# %% [markdown]
# ## Summary
# ## The quantity of Food and Beverages,fashion accessories, electronic accessories and home and lifestyle purchased was greater
# ## for the female than the male.
# ## The quantity of Sports and travel items purchased were equal for both male and female.
# ## The quantity of Health and beauty products purchased by male was greater than the female.

# %%
import seaborn as sns
sns.catplot(x = "Product line",y = "Total",
                hue= "Gender",
                data= dataset,
                kind = "box", aspect = 4)

# %% [markdown]
# ## Summary
# ## Food and beverages and home and lifestyle products were purchased by more female than male.
# ## Electronic accessories, fashion accessories were equally purchased by both male and female.
# ## Health and beauty items and sports and travel items were purchased by more male than female

# %%
sns.catplot(x= "Product line",y= "Unit price",
               data= dataset,
               kind = "point", aspect = 4)

# %%
sns.catplot(x= "Product line", y= "Quantity",
               data = dataset,
               kind = "point", aspect = 4)

# %% [markdown]
# ## Summary
# ## The product line with the highest unit price was purchased the least in quantity
# ## The product line with the lowest unit price was purchased the most in quantity
